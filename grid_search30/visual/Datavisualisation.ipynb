# %%
import glob
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import jax.numpy as jnp
from LRUandJaxLIB import *
import os

gloober = [path for path in glob.glob("/root/Project/jax_machinelearning/grid_search30/*") if not os.path.isdir(path)]

# %%
test_file_path = "/root/Project/jax_machinelearning/datasets/8mfsk/absolute_doppler_waveforms_CNO_[14.2],[16.67]_and90_samprate_2000_1736935556.6539564.pkl"

print(gloober)

batch_size = 10

train_sequences, train_labels, _, __ = load_data_stft(test_file_path, batch_size, 9, 0.8)


for idk, glib in enumerate(gloober):
    with open(glib, "rb") as f:
        res = pkl.load(f)
        maximum_argument = np.argmax(res["Accuracy Measurements"]["Training accuracy"])
        model_parameters = res["Model Parameters"][maximum_argument]


   


    # Confusion matrix
    Confusion_count = np.zeros([9,9])

    Confusion_count

    for x, y in zip(train_sequences, train_labels):
        infer = np.argmax(batch_model_forward3(x, model_parameters, 0, jax.random.key(1), True),axis=1)
        truth = np.argmax(y, axis=1)
        for k,z in zip(truth, infer):
            Confusion_count[k,z] += 1

    for x, y in zip(_, __):
        infer = np.argmax(batch_model_forward3(x, model_parameters, 0, jax.random.key(1), True),axis=1)
        truth = np.argmax(y, axis=1)
        for k,z in zip(truth, infer):
            Confusion_count[k,z] += 1

    Confusion_matrix = np.zeros([9,9])
    for idx, con in enumerate(Confusion_count):
        sum = np.sum(con)
        Confusion_matrix[idx] = con/sum


    fig, ax = plt.subplots(figsize = (3,3))

    im = ax.imshow(Confusion_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)

    ax.set(xticks=np.arange(Confusion_matrix.shape[0]),
        yticks=np.arange(Confusion_matrix.shape[1]),
        xlabel = 'Predicted Label',
            ylabel = 'True Label',
            title = 'Confusion Matrix' )

    ax.set_title(f'{res["Learning Schedule"]["Value"]}')
    fig.text(0.50, 0.02,f'{res["Accuracy Measurements"]["Testing accuracy"][maximum_argument]}', 
    horizontalalignment='center', wrap=True ) 
    plt.tight_layout()
    plt.savefig(f"/root/Project/jax_machinelearning/grid_search30/visual/confusion{idk}.pdf")
    #plt.show()

    np.trace(Confusion_matrix)/np.sum(Confusion_matrix)
# Out:
# ['/root/Project/jax_machinelearning/grid_search30/results2 time 2025-01-15 10:17:28.704851.pkl', '/root/Project/jax_machinelearning/grid_search30/results2 time 2025-01-15 10:20:16.916970.pkl', '/root/Project/jax_machinelearning/grid_search30/results1 time 2025-01-15 10:16:32.526952.pkl', '/root/Project/jax_machinelearning/grid_search30/results2 time 2025-01-15 10:11:52.133646.pkl', '/root/Project/jax_machinelearning/grid_search30/results0 time 2025-01-15 10:12:48.003478.pkl', '/root/Project/jax_machinelearning/grid_search30/results0 time 2025-01-15 10:15:36.223362.pkl', '/root/Project/jax_machinelearning/grid_search30/results2 time 2025-01-15 10:14:40.164008.pkl', '/root/Project/jax_machinelearning/grid_search30/results0 time 2025-01-15 10:09:47.435502.pkl', '/root/Project/jax_machinelearning/grid_search30/results0 time 2025-01-15 10:18:24.867574.pkl', '/root/Project/jax_machinelearning/grid_search30/results1 time 2025-01-15 10:13:44.116141.pkl', '/root/Project/jax_machinelearning/grid_search30/results1 time 2025-01-15 10:19:20.899455.pkl', '/root/Project/jax_machinelearning/grid_search30/results1 time 2025-01-15 10:10:55.909838.pkl']
